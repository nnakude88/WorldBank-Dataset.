# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set()

# %%
wb = pd.read_excel("WorldBank.xlsx")
wb
# Out:
#       Country Name Country Code              Region IncomeGroup  Year  \
# 0      Afghanistan          AFG          South Asia  Low income  2018
# 1      Afghanistan          AFG          South Asia  Low income  2017
# 2      Afghanistan          AFG          South Asia  Low income  2016
# 3      Afghanistan          AFG          South Asia  Low income  2015
# 4      Afghanistan          AFG          South Asia  Low income  2014
# ...            ...          ...                 ...         ...   ...
# 12444     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1964
# 12445     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1963
# 12446     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1962
# 12447     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1961
# 12448     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1960
#
#        Birth rate, crude (per 1,000 people)  \
# 0                                       NaN
# ...

# %%
wb.columns
# Out:
# Index(['Country Name', 'Country Code', 'Region', 'IncomeGroup', 'Year',
#        'Birth rate, crude (per 1,000 people)',
#        'Death rate, crude (per 1,000 people)',
#        'Electric power consumption (kWh per capita)', 'GDP (USD)',
#        'GDP per capita (USD)',
#        'Individuals using the Internet (% of population)',
#        'Infant mortality rate (per 1,000 live births)',
#        'Life expectancy at birth (years)',
#        'Population density (people per sq. km of land area)',
#        'Unemployment (% of total labor force) (modeled ILO estimate)'],
#       dtype='object')

# %%
wb.shape
# Out:
# (12449, 15)

# %%
wb.dtypes
# Out:
# Country Name                                                     object
# Country Code                                                     object
# Region                                                           object
# IncomeGroup                                                      object
# Year                                                              int64
# Birth rate, crude (per 1,000 people)                            float64
# Death rate, crude (per 1,000 people)                            float64
# Electric power consumption (kWh per capita)                     float64
# GDP (USD)                                                       float64
# GDP per capita (USD)                                            float64
# Individuals using the Internet (% of population)                float64
# Infant mortality rate (per 1,000 live births)                   float64
# Life expectancy at birth (years)                                float64
# ...

# %%
wb.isnull().sum()
# Out:
# Country Name                                                       0
# Country Code                                                       0
# Region                                                             0
# IncomeGroup                                                        0
# Year                                                               0
# Birth rate, crude (per 1,000 people)                            1009
# Death rate, crude (per 1,000 people)                            1033
# Electric power consumption (kWh per capita)                     6601
# GDP (USD)                                                       2871
# GDP per capita (USD)                                            2874
# Individuals using the Internet (% of population)                7385
# Infant mortality rate (per 1,000 live births)                   2465
# Life expectancy at birth (years)                                1273
# Population density (people per sq. km of land area)              604
# ...

# %%
wb["Birth rate, crude (per 1,000 people)"].mean()
# Out:
# 28.643276420454548

# %%
wb["Birth rate, crude (per 1,000 people)"] = wb["Birth rate, crude (per 1,000 people)"].fillna(28)

# %%
wb["Death rate, crude (per 1,000 people)"].mean()
# Out:
# 10.58853901804485

# %%
wb["Death rate, crude (per 1,000 people)"] = wb["Death rate, crude (per 1,000 people)"].fillna(10.5)

# %%
wb["Electric power consumption (kWh per capita)"].mean()
# Out:
# 3175.29468627736

# %%
wb["Electric power consumption (kWh per capita)"] = wb["Electric power consumption (kWh per capita)"].fillna(3175)

# %%
wb["GDP (USD)"].mode()
# Out:
# 0    1.150000e+11
# Name: GDP (USD), dtype: float64

# %%
wb["GDP (USD)"] = wb["GDP (USD)"].fillna(1.150000e+11)

# %%
wb["GDP per capita (USD)"].mean()
# Out:
# 8231.812258882506

# %%
wb["GDP per capita (USD)"] = wb["GDP per capita (USD)"].fillna(8231)

# %%
wb["Individuals using the Internet (% of population)"].mean()
# Out:
# 23.334470976944115

# %%
wb["Individuals using the Internet (% of population)"] = wb["Individuals using the Internet (% of population)"].fillna(23)

# %%
wb["Infant mortality rate (per 1,000 live births)"].mean()
# Out:
# 51.70443709935897

# %%
wb["Infant mortality rate (per 1,000 live births)"] = wb["Infant mortality rate (per 1,000 live births)"].fillna(51)

# %%
wb["Life expectancy at birth (years)"].mean()
# Out:
# 64.04469248389405

# %%
wb["Life expectancy at birth (years)"] = wb["Life expectancy at birth (years)"].fillna(64)

# %%
wb["Population density (people per sq. km of land area)"].mean()
# Out:
# 318.8613704823554

# %%
wb["Population density (people per sq. km of land area)"] = wb["Population density (people per sq. km of land area)"].fillna(318)

# %%
wb["Unemployment (% of total labor force) (modeled ILO estimate)"].mode()
# Out:
# 0    3.6
# Name: Unemployment (% of total labor force) (modeled ILO estimate), dtype: float64

# %%
wb["Unemployment (% of total labor force) (modeled ILO estimate)"] = wb["Unemployment (% of total labor force) (modeled ILO estimate)"].fillna(3.6)

# %%
wb.isnull().sum()
# Out:
# Country Name                                                    0
# Country Code                                                    0
# Region                                                          0
# IncomeGroup                                                     0
# Year                                                            0
# Birth rate, crude (per 1,000 people)                            0
# Death rate, crude (per 1,000 people)                            0
# Electric power consumption (kWh per capita)                     0
# GDP (USD)                                                       0
# GDP per capita (USD)                                            0
# Individuals using the Internet (% of population)                0
# Infant mortality rate (per 1,000 live births)                   0
# Life expectancy at birth (years)                                0
# Population density (people per sq. km of land area)             0
# ...

# %%
wb["Region"].unique()
# Out:
# array(['South Asia', 'Europe & Central Asia',
#        'Middle East & North Africa', 'East Asia & Pacific',
#        'Sub-Saharan Africa', 'Latin America & Caribbean', 'North America'],
#       dtype=object)

# %%
wb["Year"].unique()
# Out:
# array([2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008,
#        2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000, 1999, 1998, 1997,
#        1996, 1995, 1994, 1993, 1992, 1991, 1990, 1989, 1988, 1987, 1986,
#        1985, 1984, 1983, 1982, 1981, 1980, 1979, 1978, 1977, 1976, 1975,
#        1974, 1973, 1972, 1971, 1970, 1969, 1968, 1967, 1966, 1965, 1964,
#        1963, 1962, 1961, 1960], dtype=int64)

# %%
wb["population_growth_rate"] =wb["Birth rate, crude (per 1,000 people)"] - wb["Death rate, crude (per 1,000 people)"] / 10

# %%
wb["Total_electricity_consumption"] = wb["Death rate, crude (per 1,000 people)"] * wb["Population density (people per sq. km of land area)"]

# %%
wb["Total_GDP"] = wb["GDP per capita (USD)"] * wb["Population density (people per sq. km of land area)"]

# %%
wb.columns
# Out:
# Index(['Country Name', 'Country Code', 'Region', 'IncomeGroup', 'Year',
#        'Birth rate, crude (per 1,000 people)',
#        'Death rate, crude (per 1,000 people)',
#        'Electric power consumption (kWh per capita)', 'GDP (USD)',
#        'GDP per capita (USD)',
#        'Individuals using the Internet (% of population)',
#        'Infant mortality rate (per 1,000 live births)',
#        'Life expectancy at birth (years)',
#        'Population density (people per sq. km of land area)',
#        'Unemployment (% of total labor force) (modeled ILO estimate)',
#        'population_growth_rate', 'Total_electricity_consumption', 'Total_GDP'],
#       dtype='object')

# %%
# Scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='GDP per capita (USD)', y='Life expectancy at birth (years)', data=wb)
plt.title('GDP per capita vs. Life expectancy at birth')
plt.xlabel('GDP per capita (USD)')
plt.ylabel('Life expectancy at birth (years)')
plt.grid(True)
plt.show()

# %%
# Line plot
plt.figure(figsize=(10, 6))
sns.lineplot(x='Year', y='GDP (USD)', data=wb)
plt.title('GDP over years')
plt.xlabel('Year')
plt.ylabel('GDP (USD)')
plt.grid(True)
plt.show()

# %%
# Bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='IncomeGroup', y='Infant mortality rate (per 1,000 live births)', data=wb)
plt.title('Infant mortality rate by Income Group')
plt.xlabel('Income Group')
plt.ylabel('Infant mortality rate (per 1,000 live births)')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Scatter plot for GDP per capita vs. Internet usage
plt.figure(figsize=(10, 6))
sns.scatterplot(x='GDP per capita (USD)', y='Individuals using the Internet (% of population)', data=wb)
plt.title('GDP per capita vs. Internet Usage')
plt.xlabel('GDP per capita (USD)')
plt.ylabel('Internet Usage (% of population)')
plt.grid(True)
plt.show()

# %%
# Calculate correlation matrix
corr_matrix = wb[['GDP per capita (USD)', 'Life expectancy at birth (years)', 'Infant mortality rate (per 1,000 live births)',
                  'Population density (people per sq. km of land area)', 'Unemployment (% of total labor force) (modeled ILO estimate)']].corr()
# Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Line plot
plt.figure(figsize=(10, 6))
sns.lineplot(x='Year', y='Life expectancy at birth (years)', data=wb)
plt.title('Life expectancy over the years')
plt.xlabel('Year')
plt.ylabel('Life expectancy at birth (years)')
plt.grid(True)
plt.show()

# %%
# Line plot
plt.figure(figsize=(10, 6))
sns.lineplot(x='Year', y='Individuals using the Internet (% of population)', data=wb)
plt.title('Individuals using internet over the years')
plt.xlabel('Year')
plt.ylabel('Individuals using the Internet (% of population)')
plt.grid(True)
plt.show()

# %%
# Line plot
plt.figure(figsize=(10, 6))
sns.lineplot(x='Year', y='GDP per capita (USD)', data=wb)
plt.title('GDP per capita over the years')
plt.xlabel('Year')
plt.ylabel('GDP per capita (USD)')
plt.grid(True)
plt.show()

# %%
# Line plot
plt.figure(figsize=(10, 6))
sns.lineplot(x='Year', y='Electric power consumption (kWh per capita)', data=wb)
plt.title('Electric power consumption over the years')
plt.xlabel('Year')
plt.ylabel('Electric power consumption (kWh per capita)')
plt.grid(True)
plt.show()

# %%
# Line plot
plt.figure(figsize=(10, 6))
sns.lineplot(x='Year', y='Birth rate, crude (per 1,000 people)', data=wb)
plt.title('Birthrate over years')
plt.xlabel('Year')
plt.ylabel('Birth rate, crude (per 1,000 people)')
plt.grid(True)
plt.show()

# %%
# Line plot
plt.figure(figsize=(10, 6))
sns.lineplot(x='Year', y='population_growth_rate', data=wb)
plt.title('Population growth over years')
plt.xlabel('Year')
plt.ylabel('population_growth_rate')
plt.grid(True)
plt.show()

# %%
# Bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Region', y='Total_GDP', data=wb)
plt.title('Region by Total GDP')
plt.xlabel('Region')
plt.ylabel('Total_GDP')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Region', y='Infant mortality rate (per 1,000 live births)', data=wb)
plt.title('Region by Infant mortality')
plt.xlabel('Region')
plt.ylabel('Infant mortality rate (per 1,000 live births))')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Region', y='Electric power consumption (kWh per capita)', data=wb)
plt.title('Region by Electric power consumption')
plt.xlabel('Region')
plt.ylabel('Electric power consumption (kWh per capita)')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Region', y='Population density (people per sq. km of land area)', data=wb)
plt.title('Region by Population density')
plt.xlabel('Region')
plt.ylabel('Population density (people per sq. km of land area)')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Region', y='Life expectancy at birth (years)', data=wb)
plt.title('Region by Life expectancy at birth')
plt.xlabel('Region')
plt.ylabel('Life expectancy at birth (years)')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
wb.columns
# Out:
# Index(['Country Name', 'Country Code', 'Region', 'IncomeGroup', 'Year',
#        'Birth rate, crude (per 1,000 people)',
#        'Death rate, crude (per 1,000 people)',
#        'Electric power consumption (kWh per capita)', 'GDP (USD)',
#        'GDP per capita (USD)',
#        'Individuals using the Internet (% of population)',
#        'Infant mortality rate (per 1,000 live births)',
#        'Life expectancy at birth (years)',
#        'Population density (people per sq. km of land area)',
#        'Unemployment (% of total labor force) (modeled ILO estimate)',
#        'population_growth_rate', 'Total_electricity_consumption', 'Total_GDP'],
#       dtype='object')

# %%
# Top Ten Country total electricity consumption).
Top_ten_GDP = wb.sort_values(by = "Total_electricity_consumption", ascending=False).head(10)
print("Top Ten Countries by Total eclectricity consumption:")
print(Top_ten_GDP[["Country Name",'GDP (USD)',]])
# Out:
# Top Ten Countries by Total eclectricity consumption:
#           Country Name     GDP (USD)
# 7330            Monaco  4.110170e+09
# 6608  Macao SAR, China  5.454520e+10
# 7317            Monaco  6.400950e+09
# 7320            Monaco  7.060240e+09
# 7321            Monaco  6.553370e+09
# 7322            Monaco  5.743030e+09
# 7323            Monaco  6.080340e+09
# 7324            Monaco  5.362650e+09
# 7325            Monaco  5.451650e+09
# 7326            Monaco  6.476490e+09

# %%
# Top Ten Country by GDP(USD).
Top_ten_GDP = wb.sort_values(by = "Total_GDP", ascending=False).head(10)
print("Top Ten Countries by Total GDP:")
print(Top_ten_GDP[["Total_GDP","Country Name"]])
# Out:
# Top Ten Countries by Total GDP:
#          Total_GDP Country Name
# 7320  3.530120e+09       Monaco
# 7321  3.276680e+09       Monaco
# 7326  3.238249e+09       Monaco
# 7318  3.234123e+09       Monaco
# 7317  3.200472e+09       Monaco
# 7319  3.129085e+09       Monaco
# 7323  3.040173e+09       Monaco
# 7327  2.933952e+09       Monaco
# 7322  2.871517e+09       Monaco
# 7325  2.725823e+09       Monaco
